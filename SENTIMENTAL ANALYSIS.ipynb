# %% [markdown]
# # DATA PRE-PROCESSING

# %%
import pandas as pd
df = pd.read_csv("AMJATH.txt",header=None,on_bad_lines='skip',encoding='utf8')
df
# Out:
#             0                                                  1           2  \
# 0      4/5/22   6:31 PM - Messages and calls are end-to-end e...   listen to
# 1      4/5/22   6:31 PM - Amjath Kncet changed their phone nu...         NaN
# 2      4/5/22                 8:09 PM - AMJATH: Hi da I'm amjath         NaN
# 3      4/5/22                    8:09 PM - AMJATH: My new number         NaN
# 4      4/6/22                                7:01 AM - priyan: 👍         NaN
# ...       ...                                                ...         ...
# 3883  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...         NaN
# 3884  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...         NaN
# 3885  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...         NaN
# 3886  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...         NaN
# 3887  11/1/25                  1:48 PM - AMJATH: <Media omitted>         NaN
#
#                                 3
# 0      or share them. Learn more.
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 3883                          NaN
# 3884                          NaN
# 3885                          NaN
# 3886                          NaN
# 3887                          NaN
#
# [3888 rows x 4 columns]

# %%
df=df.drop(0)

# %%
df
# Out:
#             0                                                  1    2    3
# 1      4/5/22   6:31 PM - Amjath Kncet changed their phone nu...  NaN  NaN
# 2      4/5/22                 8:09 PM - AMJATH: Hi da I'm amjath  NaN  NaN
# 3      4/5/22                    8:09 PM - AMJATH: My new number  NaN  NaN
# 4      4/6/22                                7:01 AM - priyan: 👍  NaN  NaN
# 5     5/24/22                 10:56 AM - AMJATH: <Media omitted>  NaN  NaN
# ...       ...                                                ...  ...  ...
# 3883  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3884  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3885  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3886  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3887  11/1/25                  1:48 PM - AMJATH: <Media omitted>  NaN  NaN
#
# [3887 rows x 4 columns]

# %%
df=df.drop(1)
df
# Out:
#             0                                                  1    2    3
# 2      4/5/22                 8:09 PM - AMJATH: Hi da I'm amjath  NaN  NaN
# 3      4/5/22                    8:09 PM - AMJATH: My new number  NaN  NaN
# 4      4/6/22                                7:01 AM - priyan: 👍  NaN  NaN
# 5     5/24/22                 10:56 AM - AMJATH: <Media omitted>  NaN  NaN
# 6     8/12/22           4:47 PM - AMJATH: http://tpcg.io/_YE2YX0  NaN  NaN
# ...       ...                                                ...  ...  ...
# 3883  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3884  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3885  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3886  11/1/25   1:45 PM - priyan: https://www.1tamilmv.farm/i...  NaN  NaN
# 3887  11/1/25                  1:48 PM - AMJATH: <Media omitted>  NaN  NaN
#
# [3886 rows x 4 columns]

# %%
df.drop([2, 3], axis=1, inplace=True)

# %%
df
# Out:
#             0                                                  1
# 2      4/5/22                 8:09 PM - AMJATH: Hi da I'm amjath
# 3      4/5/22                    8:09 PM - AMJATH: My new number
# 4      priyan                                                  👍
# 5      AMJATH                                    <Media omitted>
# 6      AMJATH                             http://tpcg.io/_YE2YX0
# ...       ...                                                ...
# 3883   priyan   https://www.1tamilmv.farm/index.php?/forums/t...
# 3884   priyan   https://www.1tamilmv.farm/index.php?/forums/t...
# 3885   priyan   https://www.1tamilmv.farm/index.php?/forums/t...
# 3886   priyan   https://www.1tamilmv.farm/index.php?/forums/t...
# 3887   AMJATH                                    <Media omitted>
#
# [3886 rows x 2 columns]

# %%
df['Name']=Message1[0]
df['Chat']=Message1[1]

# %%
df
# Out:
#          Date                                               Chat        Time  \
# 2      4/5/22                                   Hi da I'm amjath    8:09 PM
# 3      4/5/22                                      My new number    8:09 PM
# 4      4/6/22                                                  👍    7:01 AM
# 5     5/24/22                                    <Media omitted>   10:56 AM
# 6     8/12/22                             http://tpcg.io/_YE2YX0    4:47 PM
# ...       ...                                                ...         ...
# 3883  11/1/25   https://www.1tamilmv.farm/index.php?/forums/t...    1:45 PM
# 3884  11/1/25   https://www.1tamilmv.farm/index.php?/forums/t...    1:45 PM
# 3885  11/1/25   https://www.1tamilmv.farm/index.php?/forums/t...    1:45 PM
# 3886  11/1/25   https://www.1tamilmv.farm/index.php?/forums/t...    1:45 PM
# 3887  11/1/25                                    <Media omitted>    1:48 PM
#
#          Name
# 2      AMJATH
# 3      AMJATH
# 4      priyan
# 5      AMJATH
# 6      AMJATH
# ...       ...
# 3883   priyan
# 3884   priyan
# 3885   priyan
# 3886   priyan
# 3887   AMJATH
#
# [3886 rows x 4 columns]

# %%
df=df[['Date','Time','Name','Chat']]
df
# Out:
#          Date        Time     Name  \
# 2      4/5/22    8:09 PM    AMJATH
# 3      4/5/22    8:09 PM    AMJATH
# 4      4/6/22    7:01 AM    priyan
# 5     5/24/22   10:56 AM    AMJATH
# 6     8/12/22    4:47 PM    AMJATH
# ...       ...         ...      ...
# 3883  11/1/25    1:45 PM    priyan
# 3884  11/1/25    1:45 PM    priyan
# 3885  11/1/25    1:45 PM    priyan
# 3886  11/1/25    1:45 PM    priyan
# 3887  11/1/25    1:48 PM    AMJATH
#
#                                                    Chat
# 2                                      Hi da I'm amjath
# 3                                         My new number
# 4                                                     👍
# 5                                       <Media omitted>
# 6                                http://tpcg.io/_YE2YX0
# ...                                                 ...
# 3883   https://www.1tamilmv.farm/index.php?/forums/t...
# 3884   https://www.1tamilmv.farm/index.php?/forums/t...
# 3885   https://www.1tamilmv.farm/index.php?/forums/t...
# 3886   https://www.1tamilmv.farm/index.php?/forums/t...
# 3887                                    <Media omitted>
#
# [3886 rows x 4 columns]

# %% [markdown]
# # SENTIMENTAL ANALYSIS

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
data=df
data
# Out:
#          Date        Time     Name  \
# 2      4/5/22    8:09 PM    AMJATH
# 3      4/5/22    8:09 PM    AMJATH
# 4      4/6/22    7:01 AM    priyan
# 5     5/24/22   10:56 AM    AMJATH
# 6     8/12/22    4:47 PM    AMJATH
# ...       ...         ...      ...
# 3883  11/1/25    1:45 PM    priyan
# 3884  11/1/25    1:45 PM    priyan
# 3885  11/1/25    1:45 PM    priyan
# 3886  11/1/25    1:45 PM    priyan
# 3887  11/1/25    1:48 PM    AMJATH
#
#                                                    Chat
# 2                                      Hi da I'm amjath
# 3                                         My new number
# 4                                                     👍
# 5                                       <Media omitted>
# 6                                http://tpcg.io/_YE2YX0
# ...                                                 ...
# 3883   https://www.1tamilmv.farm/index.php?/forums/t...
# 3884   https://www.1tamilmv.farm/index.php?/forums/t...
# 3885   https://www.1tamilmv.farm/index.php?/forums/t...
# 3886   https://www.1tamilmv.farm/index.php?/forums/t...
# 3887                                    <Media omitted>
#
# [3886 rows x 4 columns]

# %%
data.dropna(inplace=True)
# Out:
# /var/folders/qc/j1zhz5wd799gnfl61hmhl4kw0000gn/T/ipykernel_1786/1368182302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
sid=SentimentIntensityAnalyzer()

# %%
 def sentimentalAnalysis(data,columnname):
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        data.dropna(inplace=True)
        sid = SentimentIntensityAnalyzer()
        data = data.dropna(subset=[columnname])
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
print(data.columns)
# Out:
# Index(['Date', 'Time', 'Name', 'Chat'], dtype='object')

# %%
pos,data_Senti=sentimentalAnalysis(data,columnname='Chat')
# Out:
# /var/folders/qc/j1zhz5wd799gnfl61hmhl4kw0000gn/T/ipykernel_1786/2738220752.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)

# %%
data_Senti
# Out:
#          Date        Time     Name  \
# 2      4/5/22    8:09 PM    AMJATH
# 3      4/5/22    8:09 PM    AMJATH
# 4      4/6/22    7:01 AM    priyan
# 5     5/24/22   10:56 AM    AMJATH
# 6     8/12/22    4:47 PM    AMJATH
# ...       ...         ...      ...
# 3883  11/1/25    1:45 PM    priyan
# 3884  11/1/25    1:45 PM    priyan
# 3885  11/1/25    1:45 PM    priyan
# 3886  11/1/25    1:45 PM    priyan
# 3887  11/1/25    1:48 PM    AMJATH
#
#                                                    Chat  \
# 2                                      Hi da I'm amjath
# 3                                         My new number
# 4                                                     👍
# 5                                       <Media omitted>
# 6                                http://tpcg.io/_YE2YX0
# ...                                                 ...
# 3883   https://www.1tamilmv.farm/index.php?/forums/t...
# 3884   https://www.1tamilmv.farm/index.php?/forums/t...
# 3885   https://www.1tamilmv.farm/index.php?/forums/t...
# 3886   https://www.1tamilmv.farm/index.php?/forums/t...
# 3887                                    <Media omitted>
#
#                                                  scores  compound  Negtive  \
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3     {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'comp...    0.0772      0.0
# 4     {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 5     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 6     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# ...                                                 ...       ...      ...
# 3883  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3884  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3885  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3886  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
# 3887  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000      0.0
#
#       Postive  Neutral comp_score
# 2       0.000    1.000        pos
# 3       0.394    0.606        pos
# 4       0.000    0.000        pos
# 5       0.000    1.000        pos
# 6       0.000    1.000        pos
# ...       ...      ...        ...
# 3883    0.000    1.000        pos
# 3884    0.000    1.000        pos
# 3885    0.000    1.000        pos
# 3886    0.000    1.000        pos
# 3887    0.000    1.000        pos
#
# [3772 rows x 10 columns]

# %%
pos
# Out:
#             count
# comp_score
# pos          3703
# neg            69
